# %% [markdown]
# # Single stock analysis example in pyfolio

# %% [markdown]
# Here's a simple example where we produce a set of plots, called a tear sheet, for a stock.

# %% [markdown]
# ## Import pyfolio

# %%
# %matplotlib inline
import pyfolio as pf

# %% [markdown]
# ## Fetch the daily returns for a stock

# %%
stock_rets = pf.utils.get_symbol_rets('FB')

# %% [markdown]
# ## Create a full tear sheet for the single stock
# This will show charts about returns and shock events.

# %%
pf.create_returns_tear_sheet(stock_rets)
# Out:
# Entire data start date: 2012-05-21
# Entire data end date: 2016-05-06
#
#
# Backtest Months: 47
# Performance statistics   Backtest
# annual_return                0.33
# annual_volatility            0.43
# sharpe_ratio                 0.88
# calmar_ratio                 0.70
# stability_of_timeseries      0.95
# max_drawdown                -0.48
# omega_ratio                  1.18
# sortino_ratio                1.43
# skew                         1.79
# kurtosis                    19.25
# tail_ratio                   1.03
# common_sense_ratio           1.37
# information_ratio            0.04
# alpha                        0.23
# beta                         1.04
# Worst Drawdown Periods net drawdown in %  peak date valley date recovery date  \
# 1                                  47.90 2012-05-21  2012-09-04    2013-07-25
# 2                                  22.06 2014-03-10  2014-04-28    2014-07-24
# 0                                  16.57 2015-07-21  2015-08-24    2015-10-19
# 4                                  13.62 2015-11-11  2016-01-21    2016-01-28
# 3                                  13.51 2016-02-01  2016-02-09    2016-03-29
#
# Worst Drawdown Periods duration
# 1                           309
# 2                            99
# 0                            65
# 4                            57
# 3                            42
# [-0.052 -0.111]

# %% [markdown]
# ## Create a full tear sheet for an equal-weight portfolio of:
# * Long SPY
# * Short QQQ
# * Long GLD
# * Long TLT

# %% [markdown]
# Additionally, we set the live start date as an example.

# %%
stock_rets_SPY = pf.utils.get_symbol_rets('SPY')
stock_rets_QQQ = pf.utils.get_symbol_rets('QQQ')
stock_rets_GLD = pf.utils.get_symbol_rets('GLD')
stock_rets_TLT = pf.utils.get_symbol_rets('TLT')

# %%
import pandas as pd
portfolio_4_assets_rets = pd.DataFrame([stock_rets_SPY, 
                                        -1 * stock_rets_QQQ, 
                                        stock_rets_GLD, 
                                        stock_rets_TLT]).T.mean(axis='columns')

# %%
pf.create_full_tear_sheet(portfolio_4_assets_rets, live_start_date='2013-10-22')
